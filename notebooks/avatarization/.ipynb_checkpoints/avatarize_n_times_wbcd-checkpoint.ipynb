# %%
from lsg import *

import pandas as pd

# %%
wbcd = pd.read_csv("../../datasets/WBCD/breast_cancer_wisconsin.csv", sep = ",")
wbcd = wbcd.astype('category')
wbcd = wbcd.drop(columns= 'Sample_code_number')

wbcd.head()
# Out:
#   Clump_Thickness Uniformity_of_Cell_Size Uniformity_of_Cell_Shape  \
# 0               5                       1                        1
# 1               5                       4                        4
# 2               3                       1                        1
# 3               6                       8                        8
# 4               4                       1                        1
#
#   Marginal_Adhesion Single_Epithelial_Cell_Size Bare_Nuclei Bland_Chromatin  \
# 0                 1                           2           1               3
# 1                 5                           7          10               3
# 2                 1                           2           2               3
# 3                 1                           3           4               3
# 4                 3                           2           1               3
#
#   Normal_Nucleoli Mitoses Class
# 0               1       1     2
# 1               2       1     2
# 2               1       1     2
# 3               7       1     2
# 4               1       1     2

# %%
res = []
for iter in range (25):

    wbcd_avatarize = avatarize(wbcd, k= 20, ncp= 2, drop_duplicates= False )    
    wbcd_avatarize['iter'] = iter

    res.append(wbcd_avatarize)
# Out:
# Regarding variables types, a MCA is performed for dimension reduction
# Regarding variables types, a MCA is performed for dimension reduction
# Regarding variables types, a MCA is performed for dimension reduction
# Regarding variables types, a MCA is performed for dimension reduction
# Regarding variables types, a MCA is performed for dimension reduction
# Regarding variables types, a MCA is performed for dimension reduction
# Regarding variables types, a MCA is performed for dimension reduction
# Regarding variables types, a MCA is performed for dimension reduction
# Regarding variables types, a MCA is performed for dimension reduction
# Regarding variables types, a MCA is performed for dimension reduction
# Regarding variables types, a MCA is performed for dimension reduction
# Regarding variables types, a MCA is performed for dimension reduction
# Regarding variables types, a MCA is performed for dimension reduction
# Regarding variables types, a MCA is performed for dimension reduction
# Regarding variables types, a MCA is performed for dimension reduction

# %%
iteration = pd.concat(res, axis = 0)
iteration.sample(10)
# Out:
#     Clump_Thickness Uniformity_of_Cell_Size Uniformity_of_Cell_Shape  \
# 597               8                      10                       10
# 165               1                       1                        1
# 470               5                       1                        2
# 405               7                       3                        2
# 48                4                       6                        8
# 621               3                       2                        2
# 492               2                       1                        1
# 320              10                       5                        7
# 604               3                       1                        1
# 645               4                       1                        1
#
#     Marginal_Adhesion Single_Epithelial_Cell_Size Bare_Nuclei Bland_Chromatin  \
# 597                10                           6           2              10
# 165                 1                           2           1               3
# 470                 1                           2           2               3
# 405                 1                           3           1               1
# 48                  5                           4           1              10
# 621                 2                           2           1               1
# 492                 1                           2           2               3
# 320                 3                           3           7               3
# 604                 1                           2           1               2
# 645                 1                           2           1               3
#
#     Normal_Nucleoli Mitoses Class  iter
# 597              10       7     4    22
# 165               1       1     2     2
# 470               1       1     2    23
# 405               1       1     2     9
# 48                1       1     4     9
# 621               2       1     2    11
# 492               1       1     2    12
# 320               3       8     4     3
# 604               1       1     2    16
# 645               1       1     2    18

# %%
iteration.to_csv("../../datasets/wbcd_avatarized_25time_k10_nf_2.csv", index = False)
